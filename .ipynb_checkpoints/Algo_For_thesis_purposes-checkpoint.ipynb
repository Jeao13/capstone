# %% [markdown]
# **Multi Label Text Classification**

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.2)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)

# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import randint
import seaborn as sns # used for plot interactive graph.
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
df = pd.read_csv ("Grievance_New.csv")
print(df.shape)
df.head(3)
# Out:
# (1700, 3)
#    text_id                                          grievance offense_tag
# 0        1  I am a faculty member reporting a student who ...      12.1.1
# 1        2  As a student, I am filing a grievance against ...      12.1.1
# 2        3  I am an administrator filing on behalf of a pr...      12.1.1

# %%
pd.DataFrame(df.offense_tag.unique()).values
# Out:
# array([['12.1.1'],
#        ['12.1.3'],
#        ['12.1.4'],
#        ['12.1.5'],
#        ['12.1.6'],
#        ['12.1.7'],
#        ['12.1.8'],
#        ['12.1.9'],
#        ['12.1.10'],
#        ['12.1.11'],
#        ['12.1.12'],
#        ['12.1.13'],
#        ['12.1.14'],
#        ['13.1'],
#        ['13.2'],
#        ['13.3'],
#        ['13.4'],
#        ['13.5'],
#        ['13.6'],
#        ['13.7'],
#        ['13.8'],
#        ['13.9'],
#        ['13.10'],
#        ['13.11'],
#        ['13.12'],
#        ['13.13'],
#        ['13.14'],
#        ['13.15'],
#        ['13.16'],
#        ['13.17'],
#        ['13.18'],
#        ['13.19'],
#        ['13.20'],
#        ['13.21']], dtype=object)

# %%
df.replace({'offense_tag':
             {'12.1.1': 'attendance, punctuality, cutting classes',
              '12.1.3': 'property misuse',
             '12.1.4': 'noise disturbance',
             '12.1.5': 'posting violation',
             '12.1.6': 'notice removal',
             '12.1.7': 'littering',
              '12.1.8': 'smoking outside violation',
              '12.1.9': 'trespassing',
              '12.1.10': 'misconduct',
              '12.1.11': 'harassment',
              '12.1.12': 'provocation, fight',
              '12.1.13': 'PDA',
              '12.1.14': 'truancy',
              '13.1': 'repeat offenses',
              '13.2': 'insubordination',
              '13.3': 'smoking inside violation',
              '13.4': 'alcohol violation',
              '13.5': 'intoxication',
              '13.6': 'trespassing',
              '13.7': 'property misuse',
              '13.8': 'endangerment',
              '13.9': 'gambling',
              '13.10': 'identity fraud',
              '13.11': 'trademark misuse',
              '13.12': 'false representation',
              '13.13': 'abusive behavior',
              '13.14': 'unauthorized membership',
              '13.15': 'online misconduct',
              '13.16': 'vandalism',
              '13.17': 'academic disruption',
              '13.18': 'solicitation',
              '13.19': 'slight physical injury',
              '13.20': 'bladed weapons possession',
              '13.21': 'theft'}},
            inplace= True)
pd.DataFrame(df.offense_tag.unique())
# Out:
#                                            0
# 0   attendance, punctuality, cutting classes
# 1                            property misuse
# 2                          noise disturbance
# 3                          posting violation
# 4                             notice removal
# 5                                  littering
# 6                  smoking outside violation
# 7                                trespassing
# 8                                 misconduct
# 9                                 harassment
# 10                        provocation, fight
# 11                                       PDA
# 12                                   truancy
# 13                           repeat offenses
# 14                           insubordination
# 15                  smoking inside violation
# 16                         alcohol violation
# 17                              intoxication
# 18                              endangerment
# 19                                  gambling
# 20                            identity fraud
# 21                          trademark misuse
# 22                      false representation
# 23                          abusive behavior
# 24                   unauthorized membership
# 25                         online misconduct
# 26                                 vandalism
# 27                       academic disruption
# 28                              solicitation
# 29                    slight physical injury
# 30                 bladed weapons possession
# 31                                     theft

# %%
df['category_id'] = df['offense_tag'].factorize()[0]
category_id_df = df[['offense_tag', 'category_id']].drop_duplicates()

# %%
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'offense_tag']].values)
df.head()
# Out:
#    text_id                                          grievance  \
# 0        1  I am a faculty member reporting a student who ...
# 1        2  As a student, I am filing a grievance against ...
# 2        3  I am an administrator filing on behalf of a pr...
# 3        4  As a staff member, I want to report a student ...
# 4        5  I am a student filing a complaint about my cla...
#
#                                 offense_tag  category_id
# 0  attendance, punctuality, cutting classes            0
# 1  attendance, punctuality, cutting classes            0
# 2  attendance, punctuality, cutting classes            0
# 3  attendance, punctuality, cutting classes            0
# 4  attendance, punctuality, cutting classes            0

# %%
fig = plt.figure(figsize=(8,6))
colors = ['grey','grey','grey','grey','grey','grey','grey','grey','grey','grey','grey','grey',
    'grey','grey','grey','grey','grey','grey','grey','grey','grey']
df.groupby('offense_tag').grievance.count().sort_values().plot.barh(
    ylim=0, color=colors, title= 'Number of Grievance in Each Offenses')
plt.xlabel('Number of ocurrences', fontsize = 10);

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        ngram_range=(1, 2),
                        stop_words='english')
# We transform each complaint into a vector
features = tfidf.fit_transform(df.grievance).toarray()
labels = df.category_id
print("Each of the %d complaints is represented by %d features (TF-IDF score of unigrams and bigrams)" %(features.shape))
# Out:
# Each of the 1700 complaints is represented by 1645 features (TF-IDF score of unigrams and bigrams)

# %%
N = 3
for offense_tag, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names_out())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("n==> %s:" %(offense_tag))
  print("  * Most Correlated Unigrams are: %s" %(', '.join(unigrams[-N:])))
  print("  * Most Correlated Bigrams are: %s" %(', '.join(bigrams[-N:])))
# Out:
# n==> PDA:
#   * Most Correlated Unigrams are: kissing, public, pda
#   * Most Correlated Bigrams are: disruptive pda, complaint couple, couple laying
# n==> abusive behavior:
#   * Most Correlated Unigrams are: sending, profanity, abusive
#   * Most Correlated Bigrams are: behavior violating, behavior violated, abusive behavior
# n==> academic disruption:
#   * Most Correlated Unigrams are: sit, obstructed, protesters
#   * Most Correlated Bigrams are: protesters blocking, students staging, exam protesters
# n==> alcohol violation:
#   * Most Correlated Unigrams are: admitted, intoxicated, alcohol
#   * Most Correlated Bigrams are: admitted drinking, campus alcohol, alcohol violation
# n==> attendance, punctuality, cutting classes:
#   * Most Correlated Unigrams are: class, attendance, cutting
#   * Most Correlated Bigrams are: class violates, attendance policy, cutting class
# n==> bladed weapons possession:
#   * Most Correlated Unigrams are: brought, written, knife
#   * Most Correlated Bigrams are: swiss knife, classmate brought, box cutter
# n==> endangerment:
#   * Most Correlated Unigrams are: endangering, endangered, nearly
#   * Most Correlated Bigrams are: policy endangering, act endangered, student nearly
# n==> false representation:
#   * Most Correlated Unigrams are: representation, claiming, falsely
#   * Most Correlated Bigrams are: violation policy, violation representation, student competing
# n==> gambling:
#   * Most Correlated Unigrams are: sports, betting, gambling
#   * Most Correlated Bigrams are: campus ip, gambling violating, gambling violated
# n==> harassment:
#   * Most Correlated Unigrams are: badgering, unjust, pestering
#   * Most Correlated Bigrams are: pestering behavior, student vexes, unjust vexation
# n==> identity fraud:
#   * Most Correlated Unigrams are: falsified, enroll, documentation
#   * Most Correlated Bigrams are: usage violated, documentation usage, violation documentation
# n==> insubordination:
#   * Most Correlated Unigrams are: asked, refusing, refusal
#   * Most Correlated Bigrams are: refusal obey, order violated, student refusing
# n==> intoxication:
#   * Most Correlated Unigrams are: visibly, drinking, inebriated
#   * Most Correlated Bigrams are: complaint inebriated, drinking act, attend campus
# n==> littering:
#   * Most Correlated Unigrams are: dumping, trash, littering
#   * Most Correlated Bigrams are: littering violated, act littering, littering violating
# n==> misconduct:
#   * Most Correlated Unigrams are: engaging, misbehavior, mischief
#   * Most Correlated Bigrams are: causing misbehavior, actions violated, engaging mischief
# n==> noise disturbance:
#   * Most Correlated Unigrams are: speaker, loud, noisy
#   * Most Correlated Bigrams are: students disruptive, despite warnings, excessive noise
# n==> notice removal:
#   * Most Correlated Unigrams are: materials, taking, removal
#   * Most Correlated Bigrams are: removal materials, unauthorized removal, taking materials
# n==> online misconduct:
#   * Most Correlated Unigrams are: images, social, media
#   * Most Correlated Bigrams are: reported student, student created, social media
# n==> posting violation:
#   * Most Correlated Unigrams are: approved, material, circulation
#   * Most Correlated Bigrams are: religious pamphlets, non approved, material circulation
# n==> property misuse:
#   * Most Correlated Unigrams are: motor, pool, use
#   * Most Correlated Bigrams are: using campus, use materials, unauthorized use
# n==> provocation, fight:
#   * Most Correlated Unigrams are: fights, provoking, fight
#   * Most Correlated Bigrams are: provocation violated, student provoking, trying provoke
# n==> repeat offenses:
#   * Most Correlated Unigrams are: repeated, misconduct, offenses
#   * Most Correlated Bigrams are: dress code, minor offenses, repeated misconduct
# n==> slight physical injury:
#   * Most Correlated Unigrams are: scrapes, resulting, bruises
#   * Most Correlated Bigrams are: complained reckless, resulting minor, reckless student
# n==> smoking inside violation:
#   * Most Correlated Unigrams are: cigarette, smoke, free
#   * Most Correlated Bigrams are: smoke free, smoking cigarette, free campus
# n==> smoking outside violation:
#   * Most Correlated Unigrams are: smoking, right, zone
#   * Most Correlated Bigrams are: violation non, non smoking, smoking right
# n==> solicitation:
#   * Most Correlated Unigrams are: donations, funds, soliciting
#   * Most Correlated Bigrams are: soliciting money, classmate soliciting, students soliciting
# n==> theft:
#   * Most Correlated Unigrams are: briefly, left, stolen
#   * Most Correlated Bigrams are: tablet stolen, stolen office, left unattended
# n==> trademark misuse:
#   * Most Correlated Unigrams are: seal, university, branding
#   * Most Correlated Bigrams are: university seal, violation branding, using university
# n==> trespassing:
#   * Most Correlated Unigrams are: closed, breaking, entry
#   * Most Correlated Bigrams are: entry violated, entry violating, unauthorized entry
# n==> truancy:
#   * Most Correlated Unigrams are: mandatory, unexcused, absence
#   * Most Correlated Bigrams are: excuse request, reason unexcused, unexcused absence
# n==> unauthorized membership:
#   * Most Correlated Unigrams are: sorority, fraternity, unrecognized
#   * Most Correlated Bigrams are: unauthorized membership, affiliation violating, unauthorized affiliation
# n==> vandalism:
#   * Most Correlated Unigrams are: broken, vandalized, damaged
#   * Most Correlated Bigrams are: finding vehicle, complained group, complaint finding

# %%
X = df['grievance'] # Collection of documents
y = df['offense_tag'] # Target or the labels we want to predict (i.e., the 21 different offenses of complaints)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state = 0)

# %%
models = [
    RandomForestClassifier(n_estimators=100, max_depth=5, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
# 5 Cross-validation
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

# %%
X_train, X_test, y_train, y_test,indices_train,indices_test = train_test_split(features,
                                                               labels,
                                                               df.index, test_size=0.25,
                                                               random_state=1)
model = LinearSVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print('Offense Classification Metrics')
print(metrics.classification_report(y_test, y_pred,
                                    target_names= df['offense_tag'].unique()))
# Out:
# Offense Classification Metrics
#                                           precision    recall  f1-score   support
#
# attendance, punctuality, cutting classes       1.00      1.00      1.00        12
#                          property misuse       1.00      1.00      1.00        26
#                        noise disturbance       1.00      1.00      1.00        14
#                        posting violation       1.00      1.00      1.00        11
#                           notice removal       1.00      1.00      1.00        12
#                                littering       1.00      1.00      1.00        16
#                smoking outside violation       1.00      1.00      1.00        12
#                              trespassing       1.00      1.00      1.00        20
#                               misconduct       1.00      1.00      1.00        15
#                               harassment       1.00      1.00      1.00         7
#                       provocation, fight       1.00      1.00      1.00        13
#                                      PDA       1.00      1.00      1.00        18
#                                  truancy       1.00      1.00      1.00        13
#                          repeat offenses       1.00      1.00      1.00        15
#                          insubordination       1.00      1.00      1.00        11
#                 smoking inside violation       1.00      1.00      1.00        10
#                        alcohol violation       1.00      1.00      1.00        10
#                             intoxication       1.00      1.00      1.00         8
#                             endangerment       1.00      1.00      1.00        17
#                                 gambling       1.00      1.00      1.00        17
#                           identity fraud       1.00      1.00      1.00        19
#                         trademark misuse       1.00      1.00      1.00        10
#                     false representation       1.00      1.00      1.00        12
#                         abusive behavior       1.00      1.00      1.00        10
#                  unauthorized membership       1.00      1.00      1.00         8
#                        online misconduct       1.00      1.00      1.00        21
#                                vandalism       1.00      0.92      0.96        13
#                      academic disruption       1.00      1.00      1.00        16
#                             solicitation       1.00      1.00      1.00        11
#                   slight physical injury       1.00      1.00      1.00        10
#                bladed weapons possession       1.00      1.00      1.00         8
#                                    theft       0.91      1.00      0.95        10
#
#                                 accuracy                           1.00       425
#                                macro avg       1.00      1.00      1.00       425
#                             weighted avg       1.00      1.00      1.00       425

# %%
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt='d',
            xticklabels=category_id_df.offense_tag.values,
            yticklabels=category_id_df.offense_tag.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("CONFUSION MATRIX - LinearSVCn", size=16);

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state = 0)
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        ngram_range=(1, 2),
                        stop_words='english')
fitted_vectorizer = tfidf.fit(X_train)
tfidf_vectorizer_vectors = fitted_vectorizer.transform(X_train)
model = LinearSVC().fit(tfidf_vectorizer_vectors, y_train)

# %%
complaint = "As a staff, I want to report a student entering a classroom without authorization"
print(model.predict(fitted_vectorizer.transform([complaint])))
# Out:
# ['trespassing']
